# %%
import unittest, time, random
import urllib.request
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
from bs4 import BeautifulSoup
import pandas as pd

# %%
links = []
imgs = []
website = "https://www.google.com"

# %%
rate = [i/10 for i in range(10)]
cnt = 0

quote = '"'
newline = '\n'
colon = ' : '

# %%
browser = webdriver.Firefox(executable_path="C:\\Users\\meghc\\.wdm\\drivers\\geckodriver\\win64\\v0.29.1\\geckodriver.exe")
# Out:
# C:\Users\meghc\AppData\Local\Temp/ipykernel_37380/2587713591.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Firefox(executable_path="C:\\Users\\meghc\\.wdm\\drivers\\geckodriver\\win64\\v0.29.1\\geckodriver.exe")

# %%
browser.get("https://www.google.com/search?q=strawberry+isolated&client=firefox-b-d&sxsrf=ALiCzsYefH6YP-uu5nBSseVLjhJ6lbOpww:1658726344071&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjN_ZGUpZP5AhWSTmwGHUCzA-cQ_AUoAXoECAEQAw&biw=1536&bih=739&dpr=1.25")
content = browser.page_source
soup1 = BeautifulSoup(content, "html.parser")

# %%
soup1
# Out:
# <html dir="ltr" itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en"><head><script async="" nonce="" src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.9VzcbxpRKHk.O/m=gapi_iframes,googleapis_client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo_aUoPPaITb9EEzSW7K7ij6VHBgCQ/cb=gapi.loaded_0"></script><base href="https://www.google.com/"/><meta content="origin" name="referrer"/><script data-id="_gd" nonce="">window.WIZ_global_data = {"DpimGf":false,"EP1ykd":["/_/*","/a/cpanel","/a/cpanel/*","/about/careers/applications","/about/careers/applications-a","/about/careers/applications-a/*","/about/careers/applications/*","/buzz/c","/buzz/c/*","/cameos","/cameos/*","/cbk","/cbk/*","/coronavirus-map","/coronavirus-map/*","/covid19-map","/covid19-map/*","/covid19/exposurenotifications/select","/covid19/exposurenotifications/select/*","/discover/likes","/discover/likes/*","/display-ads-user-messaging-embed","/display-ads-user-messaging-embed/*","/finance","/finance/*","/healthinsu
# ...

# %%
for main in soup1.findAll('img', src=True):
#    time.sleep(random.choice(rate))
#    imgl = main.find('img', src=True)
#    if (imgl != ''):
        imgs.append((main.get('src')).strip())

# %%
len(imgl)

# %%
print("Got imgs : ", len(imgs))
# Out:
# Got imgs :  65

# %%
imgs
# Out:
# ['https://media.gettyimages.com/photos/banana-bunch-picture-id173242750?k=20&m=173242750&s=612x612&w=0&h=dgXrAP6otDeY5h6fhy-SRmW-2dFOCKx1_hNS1lLWF7Y=',
#  'https://media.gettyimages.com/photos/banana-picture-id157375066?k=20&m=157375066&s=612x612&w=0&h=_MQmk1tMN5szIcfwegVuuNub0_Onkj1E0fX-I10hqqk=',
#  'https://media.gettyimages.com/photos/banana-bunch-picture-id162487071?k=20&m=162487071&s=612x612&w=0&h=8E3j_qFNPqPRIbsjifXEpl7CnM-Dc1mb-0CNB2UKUK0=',
#  'https://media.gettyimages.com/photos/bunch-of-bananas-isolated-on-white-background-picture-id958873642?k=20&m=958873642&s=612x612&w=0&h=QB834HWITNRIhT_p_Vi9z4DjGeauhtFW0fPZBMAvLxQ=',
#  'https://media.gettyimages.com/photos/-picture-id868892060?k=20&m=868892060&s=612x612&w=0&h=HjHy7psesllZHZWwJQJVn8qKsA1ffwsWh6NuuTsfzk0=',
#  'https://media.gettyimages.com/photos/closeup-of-banana-against-white-background-picture-id1142174273?k=20&m=1142174273&s=612x612&w=0&h=TxugcZbo3nkUWs2cKlB5BL9yPoc1iK6UAeZwFODLS8Q=',
# ...

# %%
for img in imgs:
    
    urllib.request.urlretrieve(imgs[cnt-1], str(cnt) + '.jpg')
    time.sleep(random.choice(rate))
    cnt = cnt + 1
    if cnt == 60:
        break
