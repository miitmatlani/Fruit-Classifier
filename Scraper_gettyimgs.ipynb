# %%
import unittest, time, random
import urllib.request
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
from bs4 import BeautifulSoup
import pandas as pd

# %%
links = []
imgs = []
website = "https://www.gettyimages.in"

# %%
rate = [i/10 for i in range(10)]
cnt = 61

quote = '"'
newline = '\n'
colon = ' : '

# %%
browser = webdriver.Firefox(executable_path="C:\\Users\\meghc\\.wdm\\drivers\\geckodriver\\win64\\v0.29.1\\geckodriver.exe")
# Out:
# C:\Users\meghc\AppData\Local\Temp/ipykernel_40228/2587713591.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Firefox(executable_path="C:\\Users\\meghc\\.wdm\\drivers\\geckodriver\\win64\\v0.29.1\\geckodriver.exe")

# %%
browser.get("https://www.gettyimages.in/photos/grape-isolated?assettype=image&license=rf&alloweduse=availableforalluses&family=creative&phrase=grape%20isolated&sort=mostpopular&page=2")
content = browser.page_source
soup1 = BeautifulSoup(content, "html.parser")

# %%
soup1
# Out:
# <html class="en-gb no-js" lang="en-gb" prefix="og: http://ogp.me/ns#"><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}</style><link href="//spectrum.gettyimages.com" rel="preconnect"/><link href="//media.gettyimages.com" rel="preconnect"/><link href="//spectrum.gettyimages.com" rel="dns-prefetch"/><link href="//media.gettyimages.com" rel="dns-prefetch"/><link href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://fonts.googleapis.com/css?family=Lato:400,400i,700,700i&amp;subset=latin-ext" rel="stylesheet"/><link href="/search/assets/css/getty-01f9d80d.css" media="all" rel="stylesheet" type="text/css"/><link href="/search/assets/css/application-c3130d6f.css" media="all" rel="stylesheet" type="text/css"/><link href="https://www.gettyimages.in/photos/grape-
# ...

# %%
for main in soup1.findAll('a', attrs = {'class' : 'MosaicAsset-module__link___wwW2J'}):

    imgl = main.find('img', src=True)
    if (imgl != ''):
        imgs.append((imgl.get('src')).strip())

# %%
print("Got imgs : ", len(imgs))
# Out:
# Got imgs :  120

# %%
imgs
# Out:
# ['https://media.gettyimages.com/photos/grape-picture-id471419759?k=20&m=471419759&s=612x612&w=0&h=Xpwd8ryMnfXP7Qm_jrEvPoBvncIgt8_VhN3SW0sJicQ=',
#  'https://media.gettyimages.com/photos/black-grapes-picture-id171151560?k=20&m=171151560&s=612x612&w=0&h=zhe_zY7qicXqG3l4MuMf9UOb0JBmMmDIlGX-eQNYNNo=',
#  'https://media.gettyimages.com/photos/closeup-of-red-grapes-against-white-background-picture-id1126428068?k=20&m=1126428068&s=612x612&w=0&h=OnaUNaiRSuXDb2IVmdD_FWsaDlRLh33L5DXUtF4BMOw=',
#  'https://media.gettyimages.com/photos/bunch-of-cabernet-grapes-picture-id88309496?k=20&m=88309496&s=612x612&w=0&h=fiEL7lj9eCjNU5yo8vZdmKpXv6vm2PaS-MdNVL_R0Ek=',
#  'https://media.gettyimages.com/photos/bunch-of-green-grapes-laying-picture-id172304886?k=20&m=172304886&s=612x612&w=0&h=ULMehdAKTAUOQa6n0UOSi6eXC4dGb4t6Utb3psgtnF8=',
# ...

# %%
for img in imgs:
    
    urllib.request.urlretrieve(imgs[cnt-1], str(cnt) + '.jpg')
    time.sleep(random.choice(rate))
    cnt = cnt + 1
    if cnt == 60:
        break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40228/137233976.py in <module>
#       1 for img in imgs:
#       2
# ----> 3     urllib.request.urlretrieve(imgs[cnt-1], str(cnt) + '.jpg')
#       4     time.sleep(random.choice(rate))
#       5     cnt = cnt + 1
#
# IndexError: list index out of range
